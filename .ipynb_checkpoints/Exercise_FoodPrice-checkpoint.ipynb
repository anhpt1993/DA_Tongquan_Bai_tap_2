# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Đọc file CSV

# %%
df = pd.read_csv(r"C:\Users\PHAM THE ANH\Data Analysis_Code Gym\01. Tong quan\Bai_tap_2\FoodPrice_in_Turkey.csv",encoding = "ISO-8859-1")
df.head(20)
# Out:
#                Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0   National Average         52  Rice - Retail     5     KG      5  2013
# 1   National Average         52  Rice - Retail     5     KG      6  2013
# 2   National Average         52  Rice - Retail     5     KG     11  2013
# 3   National Average         52  Rice - Retail     5     KG     12  2013
# 4   National Average         52  Rice - Retail     5     KG      1  2014
# 5   National Average         52  Rice - Retail     5     KG      2  2014
# 6   National Average         52  Rice - Retail     5     KG      3  2014
# 7   National Average         52  Rice - Retail     5     KG      5  2014
# 8   National Average         52  Rice - Retail     5     KG      6  2014
# 9   National Average         52  Rice - Retail     5     KG      7  2014
# 10  National Average         52  Rice - Retail     5     KG      8  2014
# 11  National Average         52  Rice - Retail     5     KG      9  2014
# ...

# %% [markdown]
# # Thông tin và các thuộc tính của bộ dữ liệu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %% [markdown]
# # Gía trung bình của từng loại sản phẩm

# %%
df.groupby("ProductName")["Price"].describe()
# Out:
#                                                     count        mean  \
# ProductName
# Apples (red) - Retail                                42.0    2.392193
# Apples - Retail                                     132.0    3.885039
# Bananas - Retail                                    174.0    8.224784
# Beans (white) - Retail                              174.0    9.572830
# Bread (common) - Retail                             174.0    4.463293
# Bread (pita) - Retail                                22.0    2.404545
# Bulgur - Retail                                     174.0    3.516712
# Cabbage - Retail                                     93.0    1.723395
# Cauliflower - Retail                                 85.0    3.274868
# Cheese - Retail                                     154.0   25.522875
# Chickpeas - Retail                                  174.0   10.347860
# Cocoa (powder) - Retail                             174.0   43.802339
# ...

# %%
df.groupby("ProductName")["Price"].mean()
# Out:
# ProductName
# Apples (red) - Retail                                       2.392193
# Apples - Retail                                             3.885039
# Bananas - Retail                                            8.224784
# Beans (white) - Retail                                      9.572830
# Bread (common) - Retail                                     4.463293
# Bread (pita) - Retail                                       2.404545
# Bulgur - Retail                                             3.516712
# Cabbage - Retail                                            1.723395
# Cauliflower - Retail                                        3.274868
# Cheese - Retail                                            25.522875
# Chickpeas - Retail                                         10.347860
# Cocoa (powder) - Retail                                    43.802339
# Coffee (instant) - Retail                                  43.295493
# ...

# %%
df.groupby("ProductName")["Price"].median()
# Out:
# ProductName
# Apples (red) - Retail                                       2.37400
# Apples - Retail                                             3.81300
# Bananas - Retail                                            8.29970
# Beans (white) - Retail                                      9.57935
# Bread (common) - Retail                                     4.67200
# Bread (pita) - Retail                                       2.38500
# Bulgur - Retail                                             3.38320
# Cabbage - Retail                                            1.60950
# Cauliflower - Retail                                        3.16660
# Cheese - Retail                                            26.47805
# Chickpeas - Retail                                         10.17255
# Cocoa (powder) - Retail                                    43.98650
# Coffee (instant) - Retail                                  41.40335
# Coffee - Retail                                            42.72290
# ...
